# %%
# !git clone https://github.com/ahmmedalsaeed/feature_extraction.git
# Out:
# Cloning into 'feature_extraction'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 26 (delta 10), reused 17 (delta 5), pack-reused 0
# Unpacking objects: 100% (26/26), done.

# %%
# !pip install efficientnet_pytorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=a1513695d408e7d16591b8e54597ae1a5ed3f2b308d8f0c666ce7348059c4e58
#   Stored in directory: /root/.cache/pip/wheels/0e/cc/b2/49e74588263573ff778da58cc99b9c6349b496636a7e165be6
# Successfully built efficientnet-pytorch
# ...

# %%
! python /content/feature_extraction/feature_extraction.py --img_path /content/feature_extraction/cat.jpg --model ResNet50
# Out:
# 2022-07-24 12:40:15.244241: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...
# 102981632/102967424 [==============================] - 0s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
# ...
